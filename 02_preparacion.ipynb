# %%
import pandas as pd

# %% [markdown]
# # Cargar datos del club

# %%
datos_aura = pd.read_csv("partidos_aura.csv")
datos_aura.head()
# Out:
#   fecha_partido     equipo_local equipo_visitante  goles_local  \
# 0    2023-01-01  Atlético Python          AURA FC            2
# 1    2023-01-08       NumPy City  Atlético Python            1
# 2    2023-01-15          AURA FC      Data United            1
# 3    2023-01-22  Atlético Python      Data United            2
# 4    2023-01-29      Data United          AURA FC            5
#
#    goles_visitante  posesion_local (%)  posesion_visitante (%)  \
# 0                0                  54                      46
# 1                5                  60                      40
# 2                0                  55                      45
# 3                3                  57                      43
# 4                3                  52                      48
#
#    tiros_arco_local  tiros_arco_visitante       estadio
# 0                12                     6  Python Arena
# 1                12                     3    Estadio ML
# ...

# %% [markdown]
# # Revisar Información General

# %%
datos_aura.info()
